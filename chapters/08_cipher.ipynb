# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/08_cipher.ipynb)
#
# # 第8章 暗号

# %% [markdown]
# ## 8.1 事後否認・改ざん・なりすまし・盗聴

# %% [markdown]
# ## 8.2 暗号の基本
#
# ![図8.1 シーザー暗号（「+13」文字ずらす）を使って，アリスがボブにメッセージを送っている様子](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-1.svg)

# %%
#準備
# !apt-get install -y -qq hxtools > /dev/null

# %%
#暗号化
# !echo "hello" | rot13

# %%
#復号
# !echo "hello" | rot13 | rot13

# %% [markdown]
# ## 8.3 公開鍵暗号

# %% [markdown]
# ### 8.3.1 盗聴への対策
#
# アリスはボブの公開鍵で暗号化し，ボブはボブの秘密鍵で復号します．
#
# ![図8.2 公開鍵暗号を使った暗号化と復号](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-2.svg)
#
# ファイル|役割
# --|--
# bob-public.pem|ボブの公開鍵
# bob-private.pem|ボブの秘密鍵
# message4bob|ボブへのメッセージ
# message4bob-secret|ボブへの暗号文

# %%
#(1) ボブが公開鍵と秘密鍵を作る．
# !openssl genrsa -out bob-private.pem 2048
# !openssl rsa -in bob-private.pem -pubout -out bob-public.pem
# Out:
# writing RSA key

# %%
#公開鍵を見てみる．
# !cat bob-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAnxdn/sBgn1LK9dZPq9fs
# xgZ6CUs+836qtZgPWVieriAYADnFP0ORb+pnv7p463UPKpoXIVYOwDKtcycTNWs/
# dN9ihgK6ii3Z5SAPfAnSgO0wonNyqzZ7g+YTV+xVCe1eudpxwrUUGvlt+Fnr0hfw
# 7Vjko6non7yYghG/H74Ztf9u0XssUVWMHTTaduJgdGo+cWAuOl9Sn0nPpRF4JA6t
# P0yStfFNt2ALtHtLUUJnXvbmfSObxKi30rcIuDsbSGDXW1Rms4XbjcCjauyXn811
# eTKf+PEdgT7UU0UrWNV0IK04W9zuw+f1MM5RyVjXolhyD21Fld4HNJ+QeWYi20bK
# pQIDAQAB
# -----END PUBLIC KEY-----

# %%
#秘密鍵を見てみる（秘密鍵は本来見せたり公開したりしてはいけない）．
# !cat bob-private.pem
# Out:
# -----BEGIN PRIVATE KEY-----
# MIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQCfF2f+wGCfUsr1
# 1k+r1+zGBnoJSz7zfqq1mA9ZWJ6uIBgAOcU/Q5Fv6me/unjrdQ8qmhchVg7AMq1z
# JxM1az9032KGArqKLdnlIA98CdKA7TCic3KrNnuD5hNX7FUJ7V652nHCtRQa+W34
# WevSF/DtWOSjqeifvJiCEb8fvhm1/27ReyxRVYwdNNp24mB0aj5xYC46X1KfSc+l
# EXgkDq0/TJK18U23YAu0e0tRQmde9uZ9I5vEqLfStwi4OxtIYNdbVGazhduNwKNq
#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "Q26G3106" > message4bob

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey yabuki-public.pem -in message4bob -out report-secret
# !base64 report-secret
# Out:
# UsmA7ppqBuiAdg/qMXqFJF4pN9RjQ+zgH1Ds+3qx8MnQU+mgr4PFrv9gvA613KocWEqm7dBmnqgl
# g4vs1gLsWcJLzHQXGwbTIDnlgDA5sDeNt1aYeJzXtaJYgpCplefP4fUxqpIj59PmVxV5tum5phja
# n2iCErIZEyGe77nhVK+t+fvMaD7hYifsfumUl02HDFMuFq0he3/035qYIY9Siyzkxq/x0A0cxrlv
# 8TXZVllJZgNj2pZLu4K7tVnKjHHUdsajf/XDW5PvWuCtcJ/IljB0OzqBzmMW7hobo+XdyanJRmO4
# HzqjYcN/nyZ6UuVokR2okaXYWRCPJIK1VoX6Mg==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey bob-private.pem -in message4bob-secret
# Out:
# ��� D�b�X��]~L�s7)\p�*Af\��R2�!�����J��ŷ_	FR���~��r�i�� ��V3e
# kyּ�(����{��щ�j�!��2�Hv!j�<��¯T[{+��51��&��;�1p���,�L>�2"H�o�CҼ^$K#`lU���j�؟��!�n�v�3��DJ��(Zփ BH}���7FL���E��H~wgp�&t.6�V�+

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
